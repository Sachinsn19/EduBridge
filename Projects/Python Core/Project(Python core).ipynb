# %%
import re


class Registration: #class for accessing registration  and login details
    def creation(self):  #Function for regsitration 
        
        try:
            su=" SIGN UP "
            su=su.center(31,"%")
            print(su)
            print()
            Registration.name=input("Name :")    
            Registration.address=(input("Address :")) 
            Registration.mobile=int(input("Mobile Number:")) 
            
            if len(str(Registration.mobile))!=10:  
                print("Please Enter Valid Mobile Number !!!!!!!!")
                Registration.mobile=int(input("Mobile Number:")) 
            Registration.email=input("Email :")    
            regex= r'\b[A-Za-z0-9._%+-]+@[A-Za-z0-9.-]+\.[A-Z|a-z]{2,}\b'
            
            if(re.match(regex, Registration.email)):
                print()
            else:
                print("Invalid Email")
                Registration.email=input("Email :")  
            Registration.password=input("Password :")
                
   
        except ValueError:
            print("\nPlease Enter valid informations\n")
            
        except:
            print("Something went wrong!!!!!!.....Please Re enter your details")
            Registration.creation(self)
            
        else:
            print("\nHello ",Registration.name,"....Your Account Creation is successfull\n")
            Registration.login(self) 
         
        
    def login(self):   #Function for login and checking credibility 
        ld=" LOGIN FORM "
        ld=ld.center(31,"%")
        print(ld)
        print()
        username=input("Mobile Number :") 
        paswd=input("Password :")  
        
        
        if (str(Registration.mobile)==str(username) and str(Registration.password)==str(paswd)):
            print("\nWelcome........",Registration.name,"\nYou successfully logged in\n")
        else:
            print("You Entered wrong informations")
        
        
    def exit(self):
        print("\nThank you....",Registration.name) 
        
        
        
        
        
        
        
class SeatPayment(Registration): #class for Ticket booking details
    
    def seats1(self): #function for ticket booking in screen 1
        available=220
        
        try:
            print()
            ps=" PAYMENTS "
            ps=ps.center(31,"%")
            print(ps)
            print()
            ticket = int(input("Tickets : ")) 
            avaiable=available-ticket  
            
        except:
            print("Please Enter valid informations")
            
        else:
            print("\nPay :",ticket*120,"\n") 
            return ticket  
            
            
    def seats2(self):  #function for ticket booking in screen 2
        available=200
        
        try:
            print()
            ps=" PAYMENTS "
            ps=ps.center(31,"%")
            print(ps)
            print()
            ticket = int(input("Tickets : "))
            avaiable=available-ticket   
            
        except:
            print("Please Enter valid informations")
            
        else:
            print("\nPay :",ticket*120,"\n")  
            return ticket  
            
            
    def seats3(self):   #function for ticket booking in screen 3
        available=180
        
        try:
            print()
            ps=" PAYMENTS "
            ps=ps.center(31,"%")
            print(ps)
            print()
            ticket = int(input("Tickets: "))  
            avaiable=available-ticket    
            
        except:
            print("Please Enter valid informations")
            
        else:
            print("\nPay :",ticket*120,"\n")  
            return ticket    
            
        
        
    def screen1Selection(self,ticket):   #Function for seat selection in Screen 1 
        
        list=[]
        for i in range(65,85):  
            for j in range(1,12):
                print(chr(i)+str(j),end=" ")
                list.append(chr(i)+str(j))
            print()
            
        
        print()   
        sn="SCREEN"
        sn=sn.center(34,"=")
        print(sn)   
        print()   
            
        selecttickets=[]
        print("\nSelect Your Seats : ")
        
        for i in range(ticket):  
            select=input("")
            select=select.upper()
            selecttickets.append(select) 

            if select in list:  
                list.remove(select) 
            else:
                print("Not Available")  
                print("You selected  unavailable seat.So Please Reselect once more")
                return 0 
                break   
                
        return  selecttickets 
    
            
    def screen2Selection(self,ticket):  #Function for seat selection in Screen 2
        
        list=[]
        for i in range(65,85):   
            for j in range(1,11):
                print(chr(i)+str(j),end=" ")
                list.append(chr(i)+str(j))
            print()
        
        print()
        sn="SCREEN"
        sn=sn.center(30,"=")
        print(sn)   
        print()   
        selecttickets=[]
        print("\nSelect Your Seats : ")
        
        for i in range(ticket):  
            select=input("")
            select=select.upper()
            selecttickets.append(select)   
            
            if select in list:  
                list.remove(select)   
            else:
                print("Not Available")
                print("You selected  unavailable seat.So Please Reselect once more")
                return 0 
                break  
    
                
        return selecttickets   
                
                
    def screen3Selection(self,ticket):    #Function for seat selection in Screen 3
        
        list=[]
        for i in range(65,83):   
            for j in range(1,11):
                print(chr(i)+str(j),end=" ")
                list.append(chr(i)+str(j))
            print()
        
        print()
        sn="SCREEN"
        sn=sn.center(30,"=")
        print(sn)   
        print()   
        selecttickets=[]
        print("\nSelect Your Seats : ")
        
        for i in range(ticket):    
            select=input("")
            select=select.upper()
            selecttickets.append(select)   
            
            if select in list:  
                list.remove(select)  
            else:
                print("Not Available")
                print("You selected  unavailable seat.So Please Reselect once more")
                return 0 
                break  
                 
        return selecttickets   
        
        
    def payment(self):  #Functions payment transactions
        
        try:
            print("\n1:Debit Card   \n2:Google Pay    \n3:Phonepay\n")
            trans=int(input("Choose Your Option : ")) #choosing payment option
            
            if trans==1: #checking entered number is equal to one or not 
                num=int(input("Debit Card Number : "))
                date=input("Expiry Date :")
            elif trans==2: #cheking entered number is equal to two or not
                Gpaylink=input("Link Address :")
            elif trans==3:  #cheking entered number is equal to three or not
                Phnpaylink=input("Link Address :")
                
            else:
                print("Invalid Entry")
                print()              
        
        except:
            print("\nTransaction Unsuccessfull....\n") 
        
        else:
            print("\nTransaction Successfull....\n")  
            return 1  
            
            
            
            
            
            
class Screens(SeatPayment): #class for movie timings of the screens
    
    def __init__(self): #constructor for assigning different timings
        Screens.time1 = {1: "10.00AM-1.00PM",2: "1.10PM-4.10PM",3: "4.20PM-7.20PM",4: "7.30PM-10.30PM"}
        Screens.time2 = {1: "10.15AM-1.15PM",2: "1.25PM-4.25PM"}
        Screens.time25= {1: "4.35PM-7.35PM",2: "7.45PM-10.45PM"}
        Screens.time3 = {1: "10.30AM-1.30PM",2: "1.40PM-4.40PM"}
        Screens.time35= {1: "4.50PM-7.50PM",2: "8.00PM-10.45PM"}

        
    def screen1(self):   #Functions for movie times in screen 1
        sl=" SELECT YOUR TIME "
        sl=sl.center(31,"%")
        print()
        print(sl)
        t = int(input("\nSCREEN 1\n\n1: 10.00AM-1.00PM\n2: 1.10PM-4.10PM\n3: 4.20PM-7.20PM\n4: 7.30PM-10.30PM\n"))
        time=Screens.time1[t]
        ticket1=SeatPayment.seats1(self)
        notdone=SeatPayment.screen1Selection(self,ticket1)
        
        if notdone==0:
            SeatPayment.screen1Selection(self,ticket1)
        else: 
            c=""
            
            for i in notdone:
                c=c+" "+(i)
                head="Seat No : "+c  
            length=len(notdone)
            time=time+"\nTotal Tickets :"+str(length)+"\n"+head
            
        return time
        
        
    def screen2(self):  #Functions for morning movie times in screen 2
        sl=" SELECT YOUR TIME "
        sl=sl.center(31,"%")
        print()
        print(sl)
        t = int(input("\nSCREEN 2\n\n1: 10.15AM-1.15PM\n2: 1.25PM-4.25PM\n"))
        time=Screens.time2[t]
        ticket2=SeatPayment.seats2(self)
        notdone=SeatPayment.screen2Selection(self,ticket2)
        
        if notdone==0:
            SeatPayment.screen2Selection(self,ticket2)
        else: 
            c=""
            
            for i in notdone:
                c=c+" "+(i)
                head="Seat No : "+c
            length=len(notdone)
            time=time+"\nTotal Tickets :"+str(length)+"\n"+head
            
        return time
        
       
    def screen25(self):      #Functions for evening and night movie times in screen 2
        sl=" SELECT YOUR TIME "
        sl=sl.center(31,"%")
        print()
        print(sl)
        t = int(input("\nSCREEN 2\n\n3: 4.35PM-7.3PM5\n4: 7.45PM-10.45PM\n"))
        time=Screens.time25[t]
        ticket2=SeatPayment.seats2(self)
        notdone=SeatPayment.screen2Selection(self,ticket2)
        
        if notdone==0:
            SeatPayment.screen2Selection(self,ticket2)
        else: 
            c=""
            
            for i in notdone:
                c=c+" "+(i)
                head="Seat No : "+c
            length=len(notdone)
            time=time+"\nTotal Tickets :"+str(length)+"\n"+head
            
        return time
        
        
    def screen3(self):   #Functions for  morning movie times in screen 3
        sl=" SELECT YOUR TIME "
        sl=sl.center(31,"%")
        print()
        print(sl)
        t = int(input("\nSCREEN 3\n\n1: 10.30AM-1.30PM\n2: 1.40PM-4.40PM\n"))
        time=Screens.time3[t]
        ticket3=SeatPayment.seats3(self)
        notdone=SeatPayment.screen3Selection(self,ticket3)
        
        if notdone==0:
            SeatPayment.screen3Selection(self,ticket3)
        else: 
            c=""
            
            for i in notdone:
                c=c+" "+(i)
                head="Seat No : "+c
            length=len(notdone)
            time=time+"\nTotal Tickets :"+str(length)+"\n"+head
            
        return time
       
        
    def screen35(self):      #Functions for eevening and night movie times in screen 3
        sl=" SELECT YOUR TIME "
        sl=sl.center(31,"%")
        print()
        print(sl)
        t = int(input("\nSCREEN 3\n\n3: 4.50PM-7.50PM\n4: 8.00PM-10.45PM\n"))
        time=Screens.time35[t]
        ticket3=SeatPayment.seats3(self)
        notdone=SeatPayment.screen3Selection(self,ticket3)
        
        if notdone==0:
            SeatPayment.screen3Selection(self,ticket3)
        else: 
            c=""
            
            for i in notdone:
                c=c+" "+(i)
                head="Seat No : "+c
            length=len(notdone)
            time=time+"\nTotal Tickets :"+str(length)+"\n"+head
            
        return time
    
    
    
        
        
        
    
class Selection(Screens):  #class for  selection of city,movie and theater
    
    def city(self):    #function for selection of city
        ld=" LOCATIONS "
        ld=ld.center(31,"%")
        print(ld)
        
        try:
            print("\n1: City A      \n2: City B   \n3: City C   \n4: City D    \n5: City E")
            place = int(input("\nChoose Your Option : "))
        
        except:
            print("You were provided invalid informations!!!!!")
            print("You must ReLogin ................")
            Registration.exit(self)
        
        if place == 1:
            cin="\nLocation : City A"
            moviess=Selection.movies(self)
            c=moviess+cin
            return c     
       
        elif place == 2:
            cin="\nLocation : City B"
            moviess=Selection.movies(self)
            c=moviess+cin
            return c
        
        elif place == 3:
            cin="\nLocation : City C" 
            Selection.movies(self)
            c=moviess+cin
            return c
        
        elif place == 4:
            cin="\nLocation : City D"
            moviess=Selection.movies(self)
            c=moviess+cin
            return c
        
        elif place == 5:
            cin="\nLocation : City E"
            moviess=Selection.movies(self)
            c=moviess+cin
            return c
        
        else:
            print("You were provided invalid informations!!!!!")
            print("You must ReLogin ................")
            Registration.exit()
            
    
    def movies(self):       #Function for selection of movie
        ml=" MOVIES LIST "
        ml=ml.center(31,"%")
        print(ml)
        
        try:
            print("\n1:Movie ABC \n2:Movie BCD  \n3:Movie CDE  \n4:Movie DEF  \n5:Movie EFG\n")
            movie = int(input("Choose Your Option : "))
            
            if movie == 1:
                tl=" THEATERS LIST "
                tl=tl.center(31,"%")
                print(tl)
                theaterlist1={1:"Theater A",2:"Theater B",3:"Theater C",4:"Theater D",5:"Theater E"}
                print("\n1:Theater A\n2:Theater B\n3:Theater C\n4:Theater D\n5:Theater E\n")
                tnum=int(input("Choose Your Option : "))
                
                if tnum==1:
                    print("\n!!! You are selected ",theaterlist1[tnum]," !!!")
                    mname="Movies Name : Movie ABC \nTheater : "
                    scrn="\nScreen 1\nShowtime : "
                    time=Screens.screen1(self)
                    m1=mname+theaterlist1[tnum]+scrn+time
                    return m1
                
                elif tnum==2:
                    print("\n!!! You are selected ",theaterlist1[tnum]," !!!")
                    mname="Movies Name : Movie ABC \nTheater : "
                    scrn="\nScreen 1\nShowtime : "
                    time=Screens.screen1(self)
                    m1=mname+theaterlist1[tnum]+scrn+time
                    return m1
                
                elif tnum==3:
                    print("\n!!! You are selected ",theaterlist1[tnum]," !!!")
                    mname="Movies Name : Movie ABC \nTheater : "
                    scrn="\nScreen 1\nShowtime : "
                    time=Screens.screen1(self)
                    m1=mname+theaterlist1[tnum]+scrn+time
                    time=Screens.screen1(self)
                    return m1
                
                elif tnum==4:
                    print("\n!!! You are selected ",theaterlist1[tnum]," !!!")
                    mname="Movies Name : Movie ABC \nTheater : "
                
                    scrn="\nScreen 1\nShowtime : "
                    time=Screens.screen1(self)
                    m1=mname+theaterlist1[tnum]+scrn+time
                    return m1
                
                elif tnum==5:
                    print("\n!!! You are selected ",theaterlist1[tnum]," !!!")
                    mname="Movies Name : Movie ABC \nTheater : "
                    scrn="\nScreen 1\nShowtime : "
                    time=Screens.screen1(self)
                    m1=mname+theaterlist1[tnum]+scrn+time
                    return m1
                
                else:
                    print(" \nProvide Valid Number")
            
            
            elif movie==2:
                tl=" THEATERS LIST "
                tl=tl.center(31,"%")
                print(tl)
                theaterlist2={1:"Theater A",2:"Theater B",3:"Theater D"}
                print("\n1:Theater A\n2:Theater B\n3:Theater D\n")
                tnum=int(input("Choose Your Option : "))
                
                if tnum==1:
                    print("\n!!! You are selected ",theaterlist2[tnum]," !!!")
                    mname="Movies Name : Movie BCD \nTheater : "
                    scrn="\nScreen 2\nShowtime : "
                    time=Screens.screen2(self)
                    m2=mname+theaterlist2[tnum]+scrn+time
                    return m2
                
                elif tnum==2:
                    print("\n!!! You are selected ",theaterlist2[tnum]," !!!")
                    mname="Movies Name : Movie BCD \nTheater : "
                    scrn="\nScreen 2\nShowtime : "
                    time=Screens.screen2(self)
                    m2=mname+theaterlist2[tnum]+scrn+time
                    return m2
                
                elif tnum==3:
                    print("\nYou are selected ",theaterlist2[tnum]," !!!")
                    mname="Movies Name : Movie BCD \nTheater : "
                    scrn="\nScreen 2\nShowtime : "
                    time=Screens.screen2(self)
                    m2=mname+theaterlist2[tnum]+scrn+time
                    return m2
                
                else:
                    print(" \nprovide Valid Number")
            
            
            elif movie==3:
                tl=" THEATERS LIST "
                tl=tl.center(31,"%")
                print(tl)
                theaterlist3={1:"Theater B",2:"Theater C",3:"Theater D"}
                tnum=int(input("\n1:Theater B\n2:Theater C\n3:Theater D\n"))
                
                if tnum==1:
                    print("\n!!! You are selected ",theaterlist3[tnum]," !!!")
                    mname="Movies Name : Movie CDE \nTheater : "
                    scrn="\nScreen 3\nShowtime : "
                    time=Screens.screen3(self)
                    m3=mname+theaterlist3[tnum]+scrn+time
                    return m3
                
                elif tnum==2:
                    print("\n!!! You are selected ",theaterlist3[tnum]," !!!")
                    mname="Movies Name : Movie CDE \nTheater : "
                    scrn="\nScreen 2\nShowtime : "
                    time=Screens.screen2(self)
                    m3=mname+theaterlist3[tnum]+scrn+time
                    return m3
                
                elif tnum==3:
                    print("\n!!! You are selected ",theaterlist3[tnum]," !!!")
                    mname="Movies Name : Movie CDE \nTheater : "
                    scrn="\nScreen 2\nShowtime : "
                    time=Screens.screen25(self)
                    m3=mname+theaterlist3[tnum]+scrn+time
                    return m3
                
                else:
                    print("\n provide Valid Number")
            
            
            elif movie==4:
                tl=" THEATER LIST "
                tl=tl.center(31,"%")
                print(tl)
                theaterlist4={1:"Theater C",2:"Theater D",3:"Theater E"}
                tnum=int(input("\n1:Theater C\n2:Theater D\n3:Theater E\n"))
                
                if tnum==1:
                    print("\n!!! You are selected ",theaterlist4[tnum]," !!!")
                    mname="Movies Name : Movie DEF \nTheater : "
                    scrn="\nScreen 3\nShowtime : "
                    time=Screens.screen3(self)
                    m4=mname+theaterlist4[tnum]+scrn+time
                    return m4
                
                elif tnum==2:
                    print("\n!!! You are selected ",theaterlist4[tnum]," !!!")
                    mname="Movies Name : Movie DEF \nTheater : "
                    scrn="\nScreen 3\nShowtime : "
                    time=Screens.screen3(self)
                    m4=mname+theaterlist4[tnum]+scrn+time
                    return m4
                
                elif tnum==3:
                    print("\n!!! You are selected ",theaterlist4[tnum]," !!!")
                    mname="Movies Name : Movie DEF \nTheater : "
                    scrn="\nScreen 2\nShowtime : "
                    time=Screens.screen2(self)
                    m4=mname+theaterlist4[tnum]+scrn+time
                    return m4
                
                else:
                    print("\n provide Valid Number")
            
            
            elif movie==5:
                tl=" THEATER LIST "
                tl=tl.center(31,"%")
                print(tl)
                theaterlist5={1:"Theater A",2:"Theater B",3:"Theater E"}
                tnum=int(input("\n1:Theater A\n2:Theater B\n3:Theater E\n"))
                
                if tnum==1:
                    print("\n!!! You are selected ",theaterlist5[tnum]," !!!")
                    mname="Movies Name : Movie EFG \nTheater : "
                    scrn="\nScreen 3\nShowtime : "
                    time=Screens.screen3(self)
                    m5=mname+theaterlist5[tnum]+scrn+time
                    return m5
                
                elif tnum==2:
                    print("\n!!! You are selected ",theaterlist5[tnum]," !!!")
                    mname="Movies Name : Movie EFG \nTheater : "
                    scrn="\nScreen 3\nShowtime : "
                    time=time=Screens.screen35(self)
                    m5=mname+theaterlist5[tnum]+scrn+time
                    return m5
                
                elif tnum==3:
                    print("\n!!! You are selected ",theaterlist5[tnum]," !!!")
                    mname="Movies Name : Movie EFG \nTheater : "
                    scrn="\nScreen 3\nShowtime : "
                    time=Screens.screen3(self)
                    m5=mname+theaterlist5[tnum]+scrn+time
                    return m5
                
                else:
                    print("\n Provide Valid Number")
            
            
            else:
                print("Please provide valid Input :")
                Selection.movies(self)
        
        
        except:
            print("You were provided invalid informations!!!!!")
            print("You must ReLogin ................")
            Registration.exit(self)

    
    
    
    

                
st=Selection()  #creating object of class Selection
print("Hi Welcome to Movie Ticket Bnoooking: \n") #Begining the screen view to the user

try:
    choicelist1="yes"
    choice=input("Type Yes or No , If you are visiting this first time\n")
    choicelower=choice.lower()
    
    if choicelower==choicelist1:
        st.creation()
    else:
        st.login()
        
except ValueError:
    print("\nPlease Provide valid Informations\n")
    st.login()
    
except :
    print("\nYou Entered wrong username or password\n")
    st.login()


cname=st.city() #calling function city
final=st.payment() #calling function payment
                      
if final==1:  #For printing receipts after completion of all opertions
    rct=" RECEIPT "
    rct=rct.center(31,"%")
    print("\n",rct,"\n")
    print("Name :",Registration.name)
    print(cname)
# Out:
# Hi Welcome to Movie Ticket Bnoooking:
#
# Type Yes or No , If you are visiting this first time
# yes
# %%%%%%%%%%% SIGN UP %%%%%%%%%%%
#
# Name :Sachin
# Address :abcdefg
# Mobile Number:1919191919
# Email :se@gmail.com
#
# Password :123abc
#
# Hello  Sachin ....Your Account Creation is successfull
#
# %%%%%%%%%% LOGIN FORM %%%%%%%%%
#
# Mobile Number :1919191919
# Password :123abc
#
# Welcome........ Sachin
# You successfully logged in
#
# %%%%%%%%%% LOCATIONS %%%%%%%%%%
#
# 1: City A
# 2: City B
# 3: City C
# 4: City D
# 5: City E
#
# Choose Your Option : 1
# %%%%%%%%% MOVIES LIST %%%%%%%%%
#
# 1:Movie ABC
# 2:Movie BCD
# 3:Movie CDE
# 4:Movie DEF
# 5:Movie EFG
#
# Choose Your Option : 2
# %%%%%%%% THEATERS LIST %%%%%%%%
#
# 1:Theater A
# 2:Theater B
# 3:Theater D
#
# Choose Your Option : 2
#
# !!! You are selected  Theater B  !!!
#
# %%%%%%% SELECT YOUR TIME %%%%%%
#
# SCREEN 2
#
# 1: 10.15AM-1.15PM
# 2: 1.25PM-4.25PM
# 2
#
# %%%%%%%%%%% PAYMENTS %%%%%%%%%%
#
# Tickets : 2
#
# ...
